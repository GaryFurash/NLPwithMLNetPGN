// %% [markdown]
// Using the "Current" Version of the Nuget Packages prevents InferColumn from working, even though it works fine in a .net console app

// %%
#i "nuget:https://pkgs.dev.azure.com/dnceng/public/_packaging/MachineLearning/nuget/v3/index.json"
#r "nuget: Microsoft.ML.AutoML"
#r "nuget: Microsoft.Data.Analysis"
// Out:
// <div><div><strong>Restore sources</strong><ul><li><span>https://pkgs.dev.azure.com/dnceng/public/_packaging/MachineLearning/nuget/v3/index.json</span></li></ul></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.Data.Analysis, 0.23.0</span></li><li><span>Microsoft.ML.AutoML, 0.23.0</span></li></ul></div></div>
// Loading extensions from `C:\packages\microsoft.ml.automl\0.23.0\interactive-extensions\dotnet\Microsoft.ML.AutoML.Interactive.dll`
// Loading extensions from `C:\packages\microsoft.data.analysis\0.23.0\interactive-extensions\dotnet\Microsoft.Data.Analysis.Interactive.dll`
// Loading extensions from `C:\packages\skiasharp\2.88.8\interactive-extensions\dotnet\SkiaSharp.DotNet.Interactive.dll`

// %% [markdown]
// Include Libaries

// %%
using System;
using System.IO;
using Microsoft.Data.Analysis;
using Microsoft.ML;
using Microsoft.ML.AutoML;
using Microsoft.ML.Data;
using System.Threading;
using System.Threading.Tasks;

// %% [markdown]
// Define Path for Training Set

// %%
var trainDataPath = @".\Data\Sleep_health_and_lifestyle_dataset_training_data.csv";

// %% [markdown]
// Initialize ML Content

// %%
var ctx = new MLContext();

// %% [markdown]
// Auto Infer training data schema w/ Auto ML and show results

// %%
var columnInferenceResults = ctx.Auto().InferColumns(trainDataPath, "Sleep Disorder", groupColumns: false);

// %%
columnInferenceResults.ColumnInformation
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.ML.AutoML.ColumnInformation</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>LabelColumnName</td><td><div class="dni-plaintext"><pre>Sleep Disorder</pre></div></td></tr><tr><td>UserIdColumnName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>GroupIdColumnName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>ItemIdColumnName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>ExampleWeightColumnName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>SamplingKeyColumnName</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>CategoricalColumnNames</td><td><div class="dni-plaintext"><pre>[ Gender, Occupation, BMI Category ]</pre></div></td></tr><tr><td>NumericColumnNames</td><td><div class="dni-plaintext"><pre>[ Age, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level ]</pre></div></td></tr><tr><td>TextColumnNames</td><td><div class="dni-plaintext"><pre>[  ]</pre></div></td></tr><tr><td>IgnoredColumnNames</td><td><div class="dni-plaintext"><pre>[  ]</pre></div></td></tr><tr><td>ImagePathColumnNames</td><td><div class="dni-plaintext"><pre>[  ]</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// Load data into IDataView
// Central to ML Processing, serve as central data pipleine tasks representing the input and output

// %%
var textLoader = ctx.Data.CreateTextLoader(columnInferenceResults.TextLoaderOptions);
var idv = textLoader.Load(trainDataPath);

// %%
idv.Preview()
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>9 columns, 100 rows</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Schema</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Gender: String, Age: Single, Occupation: String, Sleep Duration: Single, Quality of Sleep: Single, Physical Activity Level: Single, Stress Level: Single, BMI Category: String, Sleep Disorder: String ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>9</pre></div></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Gender: String</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Gender</pre></div></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>IsHidden</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Type</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>String</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>RawType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.readonlymemory-1?view=net-7.0">System.ReadOnlyMemory&lt;System.Char&gt;</a></span></td></tr></tbody></table></div></details></td></tr><tr><td>Annotations</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code></code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Schema</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td><i>(values)</i></td><td><i>(empty)</i></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Age: Single</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Age</pre></div></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>IsHidden</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Type</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Single</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>RawType</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.single?view=net-7.0">System.Single</a></span></td></tr></tbody></table></div></details></td></tr><tr><td>Annotations</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code></code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Schema</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[  ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td><i>(values)</i></td><td><i>(empty)</i></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Occupation: String</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Occupation</pre></div></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>IsHidden</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Type</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>String</code></span></s ...

// %% [markdown]
// Split Data into Train and Test
// Reserve 20% of the data for testing

// %%
var trainTestSplit = ctx.Data.TrainTestSplit(idv, testFraction:0.2);
var trainSet = trainTestSplit.TrainSet;
var validation = trainTestSplit.TestSet;

// %% [markdown]
// Define Training Pipleine
// * Append steps that should be performed during training process
// * Provides estimators based on features provided
// * Featurizer Output: a single column containing a numerical feature vector based on the transformed column data. This is the *input* to the model build.
// * Add the Machine Learning task (MultiClassification) to be performed

// %%
var pipeline =
    ctx.Auto().Featurizer(trainSet,columnInferenceResults.ColumnInformation,outputColumnName:"Features")
        .Append(ctx.Transforms.Conversion.MapValueToKey("Sleep Disorder", "Sleep Disorder"))
        .Append(ctx.Auto().MultiClassification(labelColumnName:columnInferenceResults.ColumnInformation.LabelColumnName));

// %% [markdown]
// Configure an ML Experiment
// * Source Pipeline from above (Featurizer Output) and datasets
// * Training Time
// * Evaluation metrics (microaccuracy)

// %%
var experiment = ctx.Auto().CreateExperiment();

experiment
	.SetPipeline(pipeline)
	.SetTrainingTimeInSeconds(10)
	.SetMulticlassClassificationMetric(MulticlassClassificationMetric.MicroAccuracy, labelColumn: columnInferenceResults.ColumnInformation.LabelColumnName)
	.SetDataset(trainSet, validation);

// %% [markdown]
// Configure Logging (track progress)

// %%
ctx.Log += (object? sender, LoggingEventArgs e) =>
{
    if (e.Source.Contains("AutoMLExperiment")) Console.WriteLine(e.RawMessage);
};

// %% [markdown]
// Run Experiment

// %%
// you MUST use a CancellationToken or the test will never complete
var tcCts = new CancellationTokenSource();
var result = await experiment.RunAsync(tcCts.Token);
// Out:
// Update Running Trial - Id: 0
// Microsoft.ML.AutoML.DefaultPerformanceMonitor has been started
// current CPU: 0, current Memory(mb): 509.68359375
// maximum memory usage: , PeakMemoryUsage: 509.68359375 trialIsCancelled: False
// trial setting - {"TrialId":0,"StartedAtUtc":"2026-01-28T21:09:29.4549662Z","EndedAtUtc":null,"Parameter":{"_pipeline_":{"_SCHEMA_":"e0 * e1 * e3 * e4 * e5","e0":{"OutputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level"],"InputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level"]},"e1":{"OutputColumnNames":["Gender","Occupation","BMI Category"],"InputColumnNames":["Gender","Occupation","BMI Category"]},"e3":{"InputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level","Gender","Occupation","BMI Category"],"OutputColumnName":"Features"},"e4":{},"e5":{"NumberOfLeaves":4,"MinimumExampleCountPerLeaf":20,"NumberOfTrees":4,"MaximumBinCountPerFeature":254,"FeatureFraction":1,"LearningRate":0.09999999999999998,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features","DiskTranspose":false}},"_SCHEMA_":"e0 * e1 * e3 * e4 * e5","e0":{"OutputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level"],"InputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level"]},"e1":{"OutputColumnNames":["Gender","Occupation","BMI Category"],"InputColumnNames":["Gender","Occupation","BMI Category"]},"e10":{"L1Regularization":1,"L2Regularization":0.1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"},"e11":{"L1Regularization":1,"L2Regularization":0.1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"},"e2":{"OutputColumnNames":["Gender","Occupation","BMI Category"],"InputColumnNames":["Gender","Occupation","BMI Category"]},"e3":{"InputColumnNames":["Age","Sleep Duration","Quality of Sleep","Physical Activity Level","Stress Level","Gender","Occupation","BMI Category"],"OutputColumnName":"Features"},"e4":{},"e5":{"NumberOfLeaves":4,"MinimumExampleCountPerLeaf":20,"NumberOfTrees":4,"MaximumBinCountPerFeature":255,"FeatureFraction":1,"LearningRate":0.09999999999999998,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features","DiskTranspose":false},"e6":{"NumberOfTrees":4,"NumberOfLeaves":4,"FeatureFraction":1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"},"e7":{"NumberOfLeaves":4,"MinimumExampleCountPerLeaf":20,"LearningRate":1,"NumberOfTrees":4,"SubsampleFraction":1,"MaximumBinCountPerFeature":255,"FeatureFraction":1,"L1Regularization":2E-10,"L2Regularization":1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"},"e8":{"L1Regularization":1,"L2Regularization":1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"},"e9":{"L1Regularization":1,"L2Regularization":1,"LabelColumnName":"Sleep Disorder","FeatureColumnName":"Features"}}}
// [Source=OneHotEncodingEstimator; Term; Training, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0079358.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; Term; Training, Kind=Trace] Channel finished. Elapsed 00:00:00.0140343.
// [Source=OneHotEncodingEstimator; Term; Training, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0018687.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0017975.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0017746.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0017568.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OVA; Fitting, Kind=Trace] Channel started
// [Source=OVA; Fitting, Kind=Info] Training learner 0
// [Source=FastTreeTraining; Training, Kind=Trace] Channel started
// [Source=Converter; InitDataset, Kind=Trace] Channel started
// [Source=Converter; InitDataset, Kind=Info] Making per-feature arrays
// [Source=Converter; CreateConverter, Kind=Trace] Channel started
// [Source=Converter; InitBoundariesAndLabels, Kind=Trace] Channel started
// [Source=Converter; InitBoundariesAndLabels, Kind=Info] Changing data from row-wise to column-wise
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; CursorSplitter, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; CursorSplitter, Kind=Trace] Channel finished. Elapsed 00:00:00.0086847.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; CursorSplitter, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Consolidate, Kind=Trace] Channel started
// [Source=Label mapper; Cursor, Kind=Trace] Channel started
// [Source=Label mapper; Consolidate, Kind=Trace] Channel finished. Elapsed 00:00:00.0026704.
// [Source=Label mapper; Consolidate, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0165588.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170195.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0137515.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170306.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0167680.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170808.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0172627.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0113356.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0099943.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0172160.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0168665.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0146266.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121744.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0103578.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0086999.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0073384.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0142806.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170929.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0168735.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170439.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0151415.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0127010.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0139364.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0169180.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0151862.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0127732.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0109241.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0136431.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0124339.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0172333.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0202356.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0177920.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0160044.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0143136.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0129617.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0164941.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0174230.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0175602.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0143948.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0180886.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0162669.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0144668.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0132371.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0126613.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0168712.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0152686.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0137485.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0164002.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0149158.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0186138.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0169024.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0108751.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0153381.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0140034.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0169661.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0200823.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0169374.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170337.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0172129.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0083131.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0144792.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0169097.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0221801.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0197380.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0179413.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0162548.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0149085.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0172157.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0214954.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0198530.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0180106.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0162189.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0150334.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0235609.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0167708.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0287664.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0263191.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0245114.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0228067.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0214405.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0168965.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0210108.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0222273.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0199036.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0250130.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0233406.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0220013.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0221735.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0167046.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0228313.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0272884.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0255038.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0238078.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0224637.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0219235.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0298007.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0274085.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0255679.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0237758.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0225894.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0263356.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0208198.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0210830.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0299607.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0175106.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0166964.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0295029.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0282504.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0264429.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0247735.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0234342.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0282077.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0268137.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0251158.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0237655.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0283866.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0288355.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0286315.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// ...
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0125649.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0088923.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0083744.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0079170.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0022300.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121236.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121020.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0124200.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0120856.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0188145.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0184676.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0122672.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121353.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0120867.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0127224.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0123978.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0189905.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0153764.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0149042.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0143880.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0127087.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0123889.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0192181.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0156183.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0124457.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0194143.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0158301.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0154023.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0149292.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0181949.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121003.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0122828.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0200461.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0197003.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0159865.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0154628.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0187651.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0123333.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0202940.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0166796.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0162178.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0157187.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0152547.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0095851.
// [Source=GenericScore; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0120591.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0124548.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0206571.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0170245.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0120858.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0209954.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0121318.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0211278.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0207790.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0122059.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0186174.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0254882.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0218466.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0114927.
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0217500.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0212406.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0207791.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0151061.
// [Source=GenericScore; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0151491.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0165629.
// [Source=OneHotEncodingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0215178.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0158220.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0154035.
// [Source=GenericScore; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0092417.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0155659.
// [Source=GenericScore; Cursor, Kind=Trace] Channel disposed
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0214595.
// [Source=ColumnConcatenatingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Consolidate, Kind=Trace] Channel disposed
// [Source=Label mapper; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0149837.
// [Source=Label mapper; Cursor, Kind=Trace] Channel disposed
// [Source=GenericScore; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0159682.
// [Source=GenericScore; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0190471.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0123845.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0270331.
// [Source=MissingValueReplacingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel disposed
// [Source=ValueToKeyMappingEstimator; RowToRowMapperTransform; Cursor, Kind=Trace] Channel finished. Elapsed 00:00:00.0234094.
